# %%
import map_projection as mp
import datetime
import matplotlib.pyplot as plt
import astropy.units as u
from nustar_pysolar import planning, io

# %% [markdown]
# Issues with nustar_pysolar and conda? Just copy & paste the nustar_pysolar folder in the nust_pysolar folder into your conda environment path then manually install Python's wget via ```conda install -n environmentName conda-forge::python-wget```

# %%
# NuSTAR FOV anti-clockwise rotation from solar north in degrees (Det0 in top left originally)
nu_SNangle = 0

# %% [markdown]
# # Nov 17

# %%
#Nov.17, Orbit 1
t_obs_proj = '2021-11-17T17:59:0'
nustar_center = [1050,480] # NuSTAR FOV centre in arcsec, [0,0] is sun centre, +West, +North
psp_loc = [-363.6845968554260,-407.3499244733]#[-377.90712101827400, -429.2828588884080] # @~18:00:00, from consensus file

plt.figure(figsize=(13,12))
x_poi17, y_poi17 = [800], [400]  # points of interest
nu_SNangle17 = -30
axes = mp.reprojection(t_obs_proj, *nustar_center, [-100,0,100], rotate=nu_SNangle17, 
                       markers=[x_poi17, y_poi17], psp_loc=psp_loc)
plt.savefig('./aia_stereo_projection_Nov_17_orbit1.jpg', bbox_inches="tight")
plt.show()
# Out:
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# aia20211115_193900_0094.fits:   0%|          | 0.00/4.21M [00:00<?, ?B/s]
# Got AIA map.
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# Got STEREO-A map.
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]

# %%
#Nov.17, Orbit 2
t_obs_proj = '2021-11-17T19:34:00'
nustar_center = [-700,-100] # NuSTAR FOV centre in arcsec, [0,0] is sun centre, +West, +North
psp_loc = [-363.6845968554260,-407.3499244733]#[-377.90712101827400, -429.2828588884080] # @~18:00:00, from consensus file

plt.figure(figsize=(13,12))
x_poi17, y_poi17 = [-600, -800], [-350, 250]  # points of interest
nu_SNangle17 = -30
axes = mp.reprojection(t_obs_proj, *nustar_center, [-100,0,100], rotate=nu_SNangle17, 
                       markers=[x_poi17, y_poi17], psp_loc=psp_loc)
plt.savefig('./aia_stereo_projection_Nov_17_orbit2.jpg', bbox_inches="tight")
plt.show()
# Out:
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# Got AIA map.
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# Got STEREO-A map.
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]

# %%
#Nov.17, Orbit 3
t_obs_proj = '2021-11-17T20:10:00'
nustar_center = [-700,-100] # NuSTAR FOV centre in arcsec, [0,0] is sun centre, +West, +North
psp_loc = [-363.6845968554260,-407.3499244733]#[-377.90712101827400, -429.2828588884080] # @~18:00:00, from consensus file

plt.figure(figsize=(13,12))
x_poi17, y_poi17 = [-600, -750], [-350, 250]  # points of interest
nu_SNangle17 = -30
axes = mp.reprojection(t_obs_proj, *nustar_center, [-100,0,100], rotate=nu_SNangle17, 
                       markers=[x_poi17, y_poi17], psp_loc=psp_loc)
plt.savefig('./aia_stereo_projection_Nov_17_orbit3.jpg', bbox_inches="tight")
plt.show()
# Out:
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# Got AIA map.
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# Got STEREO-A map.
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]

# %% [markdown]
# # Nov 19

# %%
# # Example
#
# t_obs_proj = '2021-11-17T14:45:00'
# # t_obs_start = (datetime.datetime.now()+datetime.timedelta(days=5)).strftime("%Y-%m-%dT%H:%M:%S")
# nustar_center = [800,400] # NuSTAR FOV centre in arcsec, [0,0] is sun centre, +West, +North
#
# plt.figure(figsize=(13,12))
# axes = mp.reprojection(t_obs_proj, *nustar_center, [-100, 0, 100], rotate=nu_SNangle)
# plt.savefig('./aia_stereo_projection.jpg', bbox_inches="tight")
# plt.show()


# Nov 19, Orbit 1
t_obs_proj = '2021-11-19T23:01:00'
nustar_center = [-450,-90] # NuSTAR FOV centre in arcsec, [0,0] is sun centre, +West, +North
psp_loc = [91.55248819473550,-428.96840870658000]#[82.3468873479248, -442.7510665241240] # @~18:00:00, from consensus file

plt.figure(figsize=(13,12))
nu_SNangle19 = -20
x_poi19, y_poi19 = [-250, -600], [-350, 200]  # points of interest
axes = mp.reprojection(t_obs_proj, *nustar_center, [-100,0,100], rotate=nu_SNangle19, 
                       markers=[x_poi19, y_poi19], psp_loc=psp_loc)
plt.savefig('./aia_stereo_projection_Nov_19_orbit1.jpg', bbox_inches="tight")
plt.show()
# Out:
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# Got AIA map.
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# Got STEREO-A map.
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]

# %%
# Nov 19, orbit 2
t_obs_proj = '2021-11-20T00:45:00'
nustar_center = [-425,-90] # NuSTAR FOV centre in arcsec, [0,0] is sun centre, +West, +North
psp_loc = [91.55248819473550,-428.96840870658000]#[82.3468873479248, -442.7510665241240] # @~18:00:00, from consensus file

plt.figure(figsize=(13,12))
nu_SNangle19 = -20
x_poi19, y_poi19 = [-500, -250], [200, -360]  # points of interest
axes = mp.reprojection(t_obs_proj, *nustar_center, [-100,0,100], rotate=nu_SNangle19, 
                       markers=[x_poi19, y_poi19], psp_loc=psp_loc)
plt.savefig('./aia_stereo_projection_Nov_19_orbit2.jpg', bbox_inches="tight")
plt.show()
# Out:
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# Got AIA map.
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# Got STEREO-A map.
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]

# %%
# Nov 19, orbit 3
t_obs_proj = '2021-11-20T02:20:00'
nustar_center = [-400,-90] # NuSTAR FOV centre in arcsec, [0,0] is sun centre, +West, +North
psp_loc = [91.55248819473550,-428.96840870658000]#[82.3468873479248, -442.7510665241240] # @~18:00:00, from consensus file

plt.figure(figsize=(13,12))
nu_SNangle19 = -20
x_poi19, y_poi19 = [-500, -240], [200, -360]  # points of interest
axes = mp.reprojection(t_obs_proj, *nustar_center, [-100,0,100], rotate=nu_SNangle19, 
                       markers=[x_poi19, y_poi19], psp_loc=psp_loc)
plt.savefig('./aia_stereo_projection_Nov_19_orbit3.jpg', bbox_inches="tight")
plt.show()
# Out:
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# Got AIA map.
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# Got STEREO-A map.
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]

# %% [markdown]
# ***

# %% [markdown]
# **Brian's example on NuSTAR solar observation planning (https://github.com/NuSTAR/nustar_pysolar/blob/main/notebooks/Planning_Example.ipynb).**
#
# **I did have to go an manually download the planet ephemeris data file de436.bsp from https://ssd.jpl.nasa.gov/ftp/eph/planets/bsp/ since nustar_pysolar kept timing out with the website. This file is also too large to uplaod to Github.**

# %% [markdown]
# You might want to adjust the tstart from above to look over the whole observing period for NuSTAR insterad of just starting at the time the maps are projected onto.

# %%
t_obs_starts = ['2021-11-17T17:26:00', '2021-11-19T23:35:00']
t_obs_durs = [{"hours":5}, {"hours":4}]
t_obs_ends = [(datetime.datetime.strptime(t_obs_start, "%Y-%m-%dT%H:%M:%S")+datetime.timedelta(**t_obs_dur)).strftime("%Y-%m-%dT%H:%M:%S") for t_obs_start, t_obs_dur in zip(t_obs_starts, t_obs_durs)]

# %%
# Use Brian's planning Notebook: https://github.com/NuSTAR/nustar_pysolar/blob/main/notebooks/Planning_Example.ipynb

for t_obs_start, t_obs_dur, t_obs_end, ang, nustar_centers in zip(t_obs_starts, t_obs_durs, t_obs_ends, [-30,-20], [[[1050, 480], [-700,-100], [-700,-100]], [[-450,-90], [-425,-90], [-400,-90]]]):
    # Get occultation period times
    fname = io.download_occultation_times(outdir='./data/')

    # Define observing window
    orbits = planning.sunlight_periods(fname, tstart=t_obs_start, tend=t_obs_end)

    # Calculate the PA angle
    pa = planning.get_nustar_roll(t_obs_start, ang<<u.deg) # angle is anti-clockwise starting with Det0 in top-left
    print("For a \"square\" field of view, use angle=0 / 90 / 180 / 270 to have DET0 at the \nNE (top left) / SE / SW / NW corners of a square field of view.")
    print("NuSTAR Roll angle for anti-clockwise rotation of {} deg from SN @ {}: {}\n".format(ang, t_obs_start, pa))

#     # Define offset, +West, +North
#     for nc in nustar_centers:
#         print(nc)
#         offset = nc*u.arcsec

    # Loop over orbits and find pointing in RA/Dec
    print("\nStarting @ ", t_obs_start)
    for ind, orbit in enumerate(orbits):
        offset = nustar_centers[ind]*u.arcsec
        midTime = (0.5*(orbit[1] - orbit[0]) + orbit[0])
        sky_pos = planning.get_skyfield_position(midTime, offset, load_path='./data', parallax_correction=True)
        print("\nOrbit: {}".format(ind))
        print("Orbit start: {} -> Orbit end: {}".format(orbit[0], orbit[1]))
        print('Aim time: {} RA: {}, Dec: {}\n'.format(midTime, sky_pos[0], sky_pos[1]))
    print("\n\n")
# Out:
# For a "square" field of view, use angle=0 / 90 / 180 / 270 to have DET0 at the
# NE (top left) / SE / SW / NW corners of a square field of view.
# NuSTAR Roll angle for anti-clockwise rotation of -30 deg from SN @ 2021-11-17T17:26:00: 350.5679076417265 deg
#
#
# Starting @  2021-11-17T17:26:00
# 100% [........................................................] 355460 / 355460
# Orbit: 0
# Orbit start: 2021-11-17T17:27:50.000 -> Orbit end: 2021-11-17T18:30:10.000
# Aim time: 2021-11-17T17:59:00.000 RA: 232.72759223599357 deg, Dec: -18.862203769678974 deg
#
# 100% [........................................................] 355460 / 355460
# Orbit: 1
# Orbit start: 2021-11-17T19:04:20.000 -> Orbit end: 2021-11-17T20:06:50.000
# Aim time: 2021-11-17T19:35:35.000 RA: 233.2188676338457 deg, Dec: -19.199896213915082 deg
#
# 100% [........................................................] 355460 / 355460
# Orbit: 2
# Orbit start: 2021-11-17T20:41:00.000 -> Orbit end: 2021-11-17T21:43:20.000
# ...

# %% [markdown]
# ***

# %% [markdown]
# ***
